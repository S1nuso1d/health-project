# %%
📚 КУРСОВАЯ РАБОТА
## Анализ факторов, влияющих на расстройства сна

**Студент:** "Татаринцев Д.О."
**Группа:** "бПО-221""
**Руководитель:** "Ягодкин А.С."

# %%
1. Введение

В современном мире проблемы со сном затрагивают более 30% населения...

# %%
2. Данные и методы

### 2.1 Описание набора данных

# Код для загрузки данных
preprocessor = DataPreprocessor("data/Sleep_health_and_lifestyle_dataset.csv")
df = preprocessor.load_data()
display(df.head())
